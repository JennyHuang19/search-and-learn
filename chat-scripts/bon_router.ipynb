# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import re
import ast
import pandas as pd

# %% [markdown]
# # Load in chat data.

# %%
import pandas as pd

bo1_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo1_eval_rm.jsonl"
bo1_rm_df = pd.read_json(bo1_rm_path, lines=True) # rows 0, 500.
bo1_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo1_eval_rm.jsonl"
bo1_rm_df_pt2 = pd.read_json(bo1_rm_path_pt2, lines=True) # rows 500, 1500.
bo1_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo1_eval_rm.jsonl"
bo1_rm_df_pt3 = pd.read_json(bo1_rm_path_pt3, lines=True) # rows 1500, 5000.


bo2_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo2_eval_rm.jsonl"
bo2_rm_df = pd.read_json(bo2_rm_path, lines=True) # rows 0, 100.
bo2_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo2_eval_rm.jsonl"
bo2_rm_df_pt2 = pd.read_json(bo2_rm_path_pt2, lines=True) # rows 500, 1500.
bo2_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo2_eval_rm.jsonl"
bo2_rm_df_pt3 = pd.read_json(bo2_rm_path_pt3, lines=True) # rows 1500, 5000.

bo4_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo4_eval_rm.jsonl"
bo4_rm_df = pd.read_json(bo4_rm_path, lines=True) # rows 0, 500.
# bo4_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo4_eval_rm.jsonl"
# bo4_rm_df_pt2 = pd.read_json(bo4_rm_path_pt2, lines=True)
bo4_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo4_eval_rm.jsonl"
bo4_rm_df_pt3 = pd.read_json(bo4_rm_path_pt3, lines=True) # rows 500, 5000.

bo8_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo8_eval_rm.jsonl"
bo8_rm_df = pd.read_json(bo8_rm_path, lines=True)
# bo8_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo8_eval_rm.jsonl"
# bo8_rm_df_pt2 = pd.read_json(bo8_rm_path_pt2, lines=True)
bo8_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo8_eval_rm.jsonl"
bo8_rm_df_pt3 = pd.read_json(bo8_rm_path_pt3, lines=True)

bo16_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo16_eval_rm.jsonl"
bo16_rm_df = pd.read_json(bo16_rm_path, lines=True)
# bo16_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo16_eval_rm.jsonl"
# bo16_rm_df_pt2 = pd.read_json(bo16_rm_path_pt2, lines=True)
bo16_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo16_eval_rm.jsonl"
bo16_rm_df_pt3 = pd.read_json(bo16_rm_path_pt3, lines=True)

bo32_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo32_eval_rm.jsonl"
bo32_rm_df = pd.read_json(bo32_rm_path, lines=True)
# bo32_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo32_eval_rm.jsonl"
# bo32_rm_df_pt2 = pd.read_json(bo32_rm_path_pt2, lines=True)
bo32_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo32_eval_rm.jsonl"
bo32_rm_df_pt3 = pd.read_json(bo32_rm_path_pt3, lines=True)

bo1_rm_df['eval_rm'].mean()
bo2_rm_df['eval_rm'].mean()
bo4_rm_df['eval_rm'].mean()
bo8_rm_df['eval_rm'].mean()
bo16_rm_df['eval_rm'].mean()
bo32_rm_df['eval_rm'].mean()

bo1_rm_df['eval_rm'].std()
bo2_rm_df['eval_rm'].std()
bo4_rm_df['eval_rm'].std()
bo8_rm_df['eval_rm'].std()
bo16_rm_df['eval_rm'].std()
bo32_rm_df['eval_rm'].std()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 30
#      27 # bo8_rm_path_pt2 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/scored_bo8_eval_rm.jsonl"
#      28 # bo8_rm_df_pt2 = pd.read_json(bo8_rm_path_pt2, lines=True)
#      29 bo8_rm_path_pt3 = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-12/scored_bo8_eval_rm.jsonl"
# ---> 30 bo8_rm_df_pt3 = pd.read_json(bo8_rm_path_pt3, lines=True)
#      32 bo16_rm_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-aug28/scored_bo16_eval_rm.jsonl"
#      33 bo16_rm_df = pd.read_json(bo16_rm_path, lines=True)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/json/_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/json/_json.py:905, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     903 elif self.engine == "ujson":
#     904     data = self._get_data_from_filepath(filepath_or_buffer)
# --> 905     self.data = self._preprocess_data(data)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/json/_json.py:917, in JsonReader._preprocess_data(self, data)
#     915 if hasattr(data, "read") and not (self.chunksize or self.nrows):
#     916     with self:
# --> 917         data = data.read()
#     918 if not hasattr(data, "read") and (self.chunksize or self.nrows):
#     919     data = StringIO(data)
#
# File <frozen codecs>:319, in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
# bo4_rm_df.shape # bo4_rm_df_pt2.shape
bo1_rm_df = pd.concat([bo1_rm_df, bo1_rm_df_pt2, bo1_rm_df_pt3], ignore_index=True)
bo2_rm_df = pd.concat([bo2_rm_df, bo2_rm_df_pt2, bo2_rm_df_pt3], ignore_index=True)
bo4_rm_df = pd.concat([bo4_rm_df, bo4_rm_df_pt3], ignore_index=True)
bo8_rm_df = pd.concat([bo8_rm_df, bo8_rm_df_pt3], ignore_index=True)
bo16_rm_df = pd.concat([bo16_rm_df, bo16_rm_df_pt3], ignore_index=True)
bo32_rm_df = pd.concat([bo32_rm_df, bo32_rm_df_pt3], ignore_index=True)

# %%
import matplotlib.pyplot as plt

# List of (label, dataframe) tuples
datasets = [
    ("N=1", bo1_rm_df),
    ("N=2", bo2_rm_df),
    ("N=4", bo4_rm_df),
    ("N=8", bo8_rm_df),
    ("N=16", bo16_rm_df),
    ("N=32", bo32_rm_df)
]

plt.figure(figsize=(10, 6))
bins = np.linspace(0, 1, 30)
for label, df in datasets:
    plt.hist(df['eval_rm'], bins=bins, alpha=0.4, label=label, density=True, edgecolor='black', linewidth=0.5)

plt.xlabel('Evaluation score (NCSOFT/Llama-3-OffsetBias-RM-8B)')
plt.ylabel('Count')
plt.title('Distribution of eval scores')
plt.legend(title='best-of-N')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Prepare N and corresponding means and stds
Ns = [1, 2, 4, 8, 16, 32]
means = [
    bo1_rm_df['eval_rm'].mean(),
    bo2_rm_df['eval_rm'].mean(),
    bo4_rm_df['eval_rm'].mean(),
    bo8_rm_df['eval_rm'].mean(),
    bo16_rm_df['eval_rm'].mean(),
    bo32_rm_df['eval_rm'].mean()
]
stds = [
    bo1_rm_df['eval_rm'].std() / np.sqrt(1500),
    bo2_rm_df['eval_rm'].std() / np.sqrt(1100),
    bo4_rm_df['eval_rm'].std() / np.sqrt(1500),
    bo8_rm_df['eval_rm'].std() / np.sqrt(1500),
    bo16_rm_df['eval_rm'].std() / np.sqrt(1500),
    bo32_rm_df['eval_rm'].std() / np.sqrt(1500)
]

plt.figure(figsize=(8, 5))
plt.errorbar(Ns, means, yerr=stds, fmt='-o', capsize=5, color='black', label='Mean ± Std')
for i, n in enumerate(Ns):
    plt.text(n, means[i], f"{means[i]:.3f}", color='black', fontsize=9, ha='right', va='bottom')
plt.xlabel('N (best-of-N)')
plt.ylabel('Avg Reward Model Score')
plt.title('Reward Model Evaluation by N')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
bo_all_rm_df = pd.concat([bo1_rm_df, bo2_rm_df, bo4_rm_df, bo8_rm_df, bo16_rm_df, bo32_rm_df], ignore_index=True)
bo_all_rm_df = bo_all_rm_df.rename(columns={'n_completions': 'N', 'token_counts': 'token_count', 'generation_time': 'time'})
bo_all_rm_df.shape
# Out:
# (29600, 8)

# %%
bo_all_rm_df['N'].unique()
bo_all_rm_df['N'].value_counts()
# Out:
# N
# 1     5000
# 4     5000
# 8     5000
# 16    5000
# 32    5000
# 2     4600
# Name: count, dtype: int64

# %%
# For each value in token_count, take the sum of the list, call the original token_count_list, and the new column token_count
bo_all_rm_df['token_count_list'] = bo_all_rm_df['token_count']
bo_all_rm_df['token_count'] = bo_all_rm_df['token_count_list'].apply(lambda x: sum(x) if isinstance(x, list) else x)
bo_all_rm_df.head()
# Out:
#                                               prompt  \
# 0  ["Is it morally right to try to have a certain...
# 1  ["What is the difference between marriage lice...
# 2  ["explain function calling. how would you call...
# 3  ["How can I create a test set for a very rare ...
# 4  ["What is the best way to travel from Tel-Aviv...
#
#                                          completions  token_count  N  \
# 0  [ 这个问题翻译成中文是什么意思？\n答案是： 1. Is it morally right...         1513  1
# 1  [ The answer is\nA marriage license and marria...         2048  1
# 2  [ "To call a function in Python, you use the f...          343  1
# 3  [ To create a test set for a very rare categor...          610  1
# 4  [ While I don't have personal experience trave...          241  1
#
#         time        rm_scores  \
# 0   8.007366      [-4.984375]
# 1  10.146462     [2.03515625]
# 2   1.658225  [-0.0999755859]
# 3   3.101166     [-1.9921875]
# 4   1.185534  [-0.8427734375]
#
#                                        best_response   eval_rm  \
# 0   这个问题翻译成中文是什么意思？\n答案是： 1. Is it morally right ...  0.079107
# 1   The answer is\nA marriage license and marriag...  0.936162
# 2   "To call a function in Python, you use the fu...  0.999892
# 3   To create a test set for a very rare category...  1.000000
# 4   While I don't have personal experience travel...  0.999225
#
#   token_count_list
# 0           [1513]
# 1           [2048]
# 2            [343]
# 3            [610]
# 4            [241]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.2)

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

palette = sns.color_palette("Set2", n_colors=len(bo_all_rm_df["N"].unique()))

# token_count plot
df_token = bo_all_rm_df.groupby(["N"])["token_count"].mean().reset_index()
sns.barplot(
    data=df_token,
    x="N",
    y="token_count",
    hue="N",
    ax=axs[0],
    palette=palette,
    edgecolor="black"
)
axs[0].set_ylabel("Average token_count")
axs[0].set_xlabel("N")
axs[0].set_title("Average token_count by N")
axs[0].get_legend().remove()

# time plot
df_time = bo_all_rm_df.groupby(["N"])["time"].mean().reset_index()
sns.barplot(
    data=df_time,
    x="N",
    y="time",
    hue="N",
    ax=axs[1],
    palette=palette,
    edgecolor="black"
)
axs[1].set_ylabel("Average time (s)")
axs[1].set_xlabel("N")
axs[1].set_title("Average time by N")
axs[1].get_legend().remove()

for ax in axs:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3031326/3403452069.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
# /tmp/ipykernel_3031326/3403452069.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")

# %% [markdown]
# # Probe Training

# %%
# create a train test split, and keep track of indices.
from sklearn.model_selection import train_test_split

# create train/test split based on unique prompts.
unique_prompts = bo_all_rm_df['prompt'].unique()

# Split sb_idx into train/test
sb_idx_train, sb_idx_test = train_test_split(
    unique_prompts,
    test_size=0.20, # .20
    random_state=1 # 6
)

# Divide queries into train and test sets.
df_train = bo_all_rm_df[bo_all_rm_df['prompt'].isin(sb_idx_train)].reset_index(drop=True)
df_test = bo_all_rm_df[bo_all_rm_df['prompt'].isin(sb_idx_test)].reset_index(drop=True)

# %%
import matplotlib.pyplot as plt

# Compute mean accuracy by N for train and test sets
# Assuming 'eval_rm' is the accuracy metric (higher is better, e.g. reward model score)
# If accuracy is defined differently, adjust accordingly.

train_acc_by_N = df_train.groupby("N")["eval_rm"].mean().reset_index()
test_acc_by_N = df_test.groupby("N")["eval_rm"].mean().reset_index()

plt.figure(figsize=(8,6))
plt.plot(train_acc_by_N["N"], train_acc_by_N["eval_rm"], marker='o', label="Train")
plt.plot(test_acc_by_N["N"], test_acc_by_N["eval_rm"], marker='o', label="Test")
plt.xlabel("N")
plt.ylabel("Mean Accuracy (eval_rm)")
plt.title("Mean Accuracy by N (Train vs Test)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# df_train.to_csv("/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/bon_train_df.csv", index=False)
# df_test.to_csv("/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/bon_test_df.csv", index=False)
df_train = pd.read_csv("/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/bon_train_df.csv")
df_test = pd.read_csv("/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/bon_test_df.csv")

# %%
df_train.shape, df_test.shape # 6436, 2164 - 1500 unique prompts # (23700, 5900) - 5000 unique prompts.
# Out:
# ((23700, 9), (5900, 9))

# %%
df_train.head() # 2207
df_test.head() # 393
# Out:
#                                               prompt  \
# 0  ["Construct a rap battle, in the style of Epic...
# 1  ["was the historical jesus a socialist","was h...
# 2  ["What's the best first move in tic-tac-toe?",...
# 3                ["how to delete kcptun on server?"]
# 4  ["What is the scientific probability of earth ...
#
#                                          completions  token_count  N  \
# 0  [' \nPikachu: "I am the Fire-type Pokemon, I r...          812  1
# 1  [' are all rhetorical questions or statements?...           45  1
# 2  [' "What are some common win strategies in tic...           37  1
# 3  [' How do you remove the Kcptun software from ...         2048  1
# 4  ['  \nWhich statement would you choose if you ...          143  1
#
#         time       rm_scores  \
# 0   4.073164   [-5.37109375]
# 1   0.222072    [2.41796875]
# 2   0.181466  [0.2486572266]
# 3  10.199469  [-2.908203125]
# 4   0.706410  [-2.615234375]
#
#                                        best_response   eval_rm  \
# 0   \nPikachu: "I am the Fire-type Pokemon, I rad...  0.979640
# 1   are all rhetorical questions or statements?\n...  0.005613
# 2   "What are some common win strategies in tic-t...  0.253809
# 3   How do you remove the Kcptun software from a ...  0.193225
# 4    \nWhich statement would you choose if you be...  0.979782
#
#   token_count_list
# 0            [812]
# 1             [45]
# 2             [37]
# 3           [2048]
# 4            [143]

# %%
# bsub -gpu "num=1/task:mode=exclusive_process:gmodel=NVIDIAA100_SXM4_80GB" -M 200G -J chat-train-features -oo /dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-10/train-features.out -eo /dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-10/train-features.err python scripts/features/chat_extract_features_simple.py --input_csv /dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-10/bon_train_df.csv --output_dir /dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-10/train-features/ --batch_size 8

# %%
# import numpy as np

# x_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-3/test-features/X.npy"
# x = np.load(x_path)
# print(x.shape)
# x_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-10/test-features/X.npy"
# x = np.load(x_path)
# print(x.shape) # (2164, 1538)
x_path = "/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/test-features/X.npy"
x = np.load(x_path)
print(x.shape) # (5900, 1538)
# Out:
# (5900, 1538)

# %%
# load in completed predicted probabilities.
ys = np.load("/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/model/true_labels.npy")
calibrated_probs = np.load("/dccstor/gma2/mehuldamani/search-and-learn/chat-results-9-13/model/calibrated_probs.npy")

print(calibrated_probs.shape, calibrated_probs.min().item(), calibrated_probs.max().item())
print(ys.shape, ys.min().item(), ys.max().item())

ys.shape, calibrated_probs.shape
# Out:
# (5900,) 0.41390812397003174 0.9910780787467957
# (5900,) 1.913000033937351e-07 1.0
# ((5900,), (5900,))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.scatter(calibrated_probs, ys, alpha=1, s=8)
plt.xlabel("predicted scores ")
plt.ylabel("true scores")
plt.grid(True)
plt.show()

# %% [markdown]
# even though, with more training points, we see the range of scores becoming larger, this model is still drastically underestimating the full range of scores.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.scatter(calibrated_probs, ys, alpha=1, s=8)
plt.xlabel("ys")
plt.ylabel("calibrated_probs")
plt.title("Scatter plot of ys vs calibrated_probs")
plt.grid(True)
plt.show()

# %%
df_test['calibrated_probs'] = calibrated_probs

# %%
df_test.head()
# Out:
#                                               prompt  \
# 0  ["Construct a rap battle, in the style of Epic...
# 1  ["was the historical jesus a socialist","was h...
# 2  ["What's the best first move in tic-tac-toe?",...
# 3                ["how to delete kcptun on server?"]
# 4  ["What is the scientific probability of earth ...
#
#                                          completions  token_count  N  \
# 0  [' \nPikachu: "I am the Fire-type Pokemon, I r...          812  1
# 1  [' are all rhetorical questions or statements?...           45  1
# 2  [' "What are some common win strategies in tic...           37  1
# 3  [' How do you remove the Kcptun software from ...         2048  1
# 4  ['  \nWhich statement would you choose if you ...          143  1
#
#         time       rm_scores  \
# 0   4.073164   [-5.37109375]
# 1   0.222072    [2.41796875]
# 2   0.181466  [0.2486572266]
# 3  10.199469  [-2.908203125]
# 4   0.706410  [-2.615234375]
#
#                                        best_response   eval_rm  \
# 0   \nPikachu: "I am the Fire-type Pokemon, I rad...  0.979640
# 1   are all rhetorical questions or statements?\n...  0.005613
# 2   "What are some common win strategies in tic-t...  0.253809
# 3   How do you remove the Kcptun software from a ...  0.193225
# 4    \nWhich statement would you choose if you be...  0.979782
#
#   token_count_list  calibrated_probs
# 0            [812]          0.627620
# 1             [45]          0.825592
# 2             [37]          0.752046
# 3           [2048]          0.857722
# 4            [143]          0.813186

# %%
# plot a calibration plot.
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define bin edges and assign each predicted_prob to a bin
num_bins = 30
df_test["bin"] = pd.cut(calibrated_probs, bins=np.linspace(0, 1, num_bins + 1), include_lowest=True)

# Group by bins and compute average predicted prob and accuracy
calibration = df_test.groupby("bin").agg(
    avg_pred_prob=("calibrated_probs", "mean"),
    accuracy=("eval_rm", "mean"),
    count=("eval_rm", "count")
).dropna()

# Print the number of points in each bin
print(calibration["count"])

# Plot calibration curve with flipped axes
plt.figure(figsize=(8, 6))
plt.plot(calibration["avg_pred_prob"], calibration["accuracy"], marker='o', label="Model Calibration")
plt.plot([0, 1], [0, 1], 'k--', label="Perfect Calibration")
plt.xlabel("predicted prob (per bin)")
plt.ylabel("true fraction were actually positive") # among all samples where the model predicted ~p, what fraction were actually positive.
plt.title("Calibration Plot")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# bin
# (0.4, 0.433]        5
# (0.433, 0.467]     14
# (0.467, 0.5]       21
# (0.5, 0.533]       24
# (0.533, 0.567]     40
# (0.567, 0.6]       48
# (0.6, 0.633]       78
# (0.633, 0.667]    113
# (0.667, 0.7]      164
# (0.7, 0.733]      229
# (0.733, 0.767]    348
# (0.767, 0.8]      440
# (0.8, 0.833]      690
# (0.833, 0.867]    837
# (0.867, 0.9]      804
# (0.9, 0.933]      890
# (0.933, 0.967]    893
# (0.967, 1.0]      262
# Name: count, dtype: int64
# /tmp/ipykernel_2850136/3804504625.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   calibration = df_test.groupby("bin").agg(

# %% [markdown]
# # Cluster Questions by Type.

# %% [markdown]
# # Routing Results.

# %%
# Create new columns for predicted token count and time based on group means
group_means = df_train.groupby(["N"])[["token_count", "time"]].mean().reset_index()
group_means = group_means.rename(columns={"token_count": "token_count_pred", "time": "time_pred"})

# Merge these means back into df_test
df_test = df_test.merge(group_means, on=["N"], how="left")

# %%
df_test.head()
# Out:
#                                               prompt  \
# 0  ["Construct a rap battle, in the style of Epic...
# 1  ["was the historical jesus a socialist","was h...
# 2  ["What's the best first move in tic-tac-toe?",...
# 3                ["how to delete kcptun on server?"]
# 4  ["What is the scientific probability of earth ...
#
#                                          completions  token_count  N  \
# 0  [' \nPikachu: "I am the Fire-type Pokemon, I r...          812  1
# 1  [' are all rhetorical questions or statements?...           45  1
# 2  [' "What are some common win strategies in tic...           37  1
# 3  [' How do you remove the Kcptun software from ...         2048  1
# 4  ['  \nWhich statement would you choose if you ...          143  1
#
#         time       rm_scores  \
# 0   4.073164   [-5.37109375]
# 1   0.222072    [2.41796875]
# 2   0.181466  [0.2486572266]
# 3  10.199469  [-2.908203125]
# 4   0.706410  [-2.615234375]
#
#                                        best_response   eval_rm  \
# 0   \nPikachu: "I am the Fire-type Pokemon, I rad...  0.979640
# 1   are all rhetorical questions or statements?\n...  0.005613
# 2   "What are some common win strategies in tic-t...  0.253809
# 3   How do you remove the Kcptun software from a ...  0.193225
# 4    \nWhich statement would you choose if you be...  0.979782
#
#   token_count_list  calibrated_probs             bin  token_count_pred  \
# 0            [812]          0.627620    (0.6, 0.633]        916.341744
# 1             [45]          0.825592    (0.8, 0.833]        916.341744
# 2             [37]          0.752046  (0.733, 0.767]        916.341744
# 3           [2048]          0.857722  (0.833, 0.867]        916.341744
# 4            [143]          0.813186    (0.8, 0.833]        916.341744
#
#    time_pred
# 0   4.597295
# 1   4.597295
# 2   4.597295
# 3   4.597295
# 4   4.597295

# %%
# get the average accuracy and token_count for each configuration.
config_summary_df = df_test.groupby(["N"])[
    ["token_count", "time", "eval_rm", "calibrated_probs", "token_count_pred", "time_pred"]
].mean().reset_index()

# %%
config_summary_df
# Out:
#     N   token_count       time   eval_rm  calibrated_probs  token_count_pred  \
# 0   1    875.247743   4.388919  0.765076          0.821887        916.341744
# 1   2   1829.339891   6.212457  0.807857          0.823924       1817.973677
# 2   4   3643.478435   7.968400  0.849004          0.830441       3640.493880
# 3   8   7295.425276   9.262573  0.868470          0.841305       7308.048713
# 4  16  14564.878636  10.355629  0.874678          0.861181      14577.723707
# 5  32  29146.909729  13.015185  0.900084          0.893830      29067.636023
#
#    time_pred
# 0   4.597295
# 1   6.199320
# 2   7.925942
# 3   9.035709
# 4  10.368374
# 5  12.900762

# %%
df_test['prompt'].nunique()
# Out:
# 983

# %%
# route for a given lambda.
def compute_max_utility_pred(df, lambda_, method="oracle", cost="token_count"):
    def get_max_utility(group):
        group = group.copy()
        if method == "oracle":
            group["utility"] = group["eval_rm"] - lambda_ * group[cost]
        elif method == "adaptive_router":
            group["utility"] = group["calibrated_probs"] - lambda_ * group[cost]
        else:
            raise ValueError(f"Invalid method: {method}")
        idx_max = group["utility"].idxmax()

        return pd.Series({
            "max_utility": group.loc[idx_max, "utility"],
            "max_predicted_prob": group.loc[idx_max, "calibrated_probs"],
            "max_eval_rm": group.loc[idx_max, "eval_rm"],
            "max_cost": group.loc[idx_max, "token_count"],
            "max_time": group.loc[idx_max, "time"],
            "N": group.loc[idx_max, "N"]
        })

    result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
    return result_df

# %%
# route for a list of lambdas.
def get_router_df(input_df, lambda_list, method="oracle", cost="token_count"):
    results = []

    for lambda_value in lambda_list:
        adaptive_router = compute_max_utility_pred(input_df, lambda_value, method, cost)
        average_accuracy = adaptive_router["max_eval_rm"].mean() # accuracy as a percentage of questions (out of all questions in the test set) answered correctly.
        average_cost = adaptive_router["max_cost"].mean() # average over all questions in test set for adaptive router.
        average_time = adaptive_router["max_time"].mean()
        average_predicted_prob = adaptive_router["max_predicted_prob"].mean()
        
        results.append({
            "lambda": lambda_value,
            "eval_rm": average_accuracy,
            "predicted_prob": average_predicted_prob,
            "token_count": average_cost,
            "time": average_time,
        })

    # Convert to DataFrame
    output_df = pd.DataFrame(results)
    output_df["method"] = method

    return output_df

# %%
oracle_tc = get_router_df(df_test, lambda_list=np.logspace(-7, -1, num=50), method="oracle", cost="token_count")
adaptive_tc = get_router_df(df_test, lambda_list=np.logspace(-7, -1, num=50), method="adaptive_router", cost="token_count_pred")
adaptive_oracle_tc = get_router_df(df_test, lambda_list=np.logspace(-7, -1, num=50), method="adaptive_router", cost="token_count")

adaptive_oracle_lat = get_router_df(df_test, lambda_list=np.logspace(-5, -1, num=50), method="adaptive_router", cost="time")
adaptive_lat = get_router_df(df_test, lambda_list=np.logspace(-5, -1, num=50), method="adaptive_router", cost="time_pred")
oracle_lat = get_router_df(df_test, lambda_list=np.logspace(-5, -1, num=50), method="oracle", cost="time")
# Out:
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# ...
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()
# /tmp/ipykernel_2850136/3768300753.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_df = df.groupby("prompt").apply(get_max_utility).reset_index()

# %%
adaptive_tc.head()
# Out:
#          lambda   eval_rm  predicted_prob   token_count       time  \
# 0  1.000000e-07  0.901713        0.893827  29210.816887  13.041404
# 1  1.325711e-07  0.901713        0.893827  29210.816887  13.041404
# 2  1.757511e-07  0.902464        0.893823  29168.162767  13.202252
# 3  2.329952e-07  0.902718        0.893819  29138.312309  12.973861
# 4  3.088844e-07  0.902718        0.893813  29125.311292  12.970872
#
#             method
# 0  adaptive_router
# 1  adaptive_router
# 2  adaptive_router
# 3  adaptive_router
# 4  adaptive_router

# %%
adaptive_lat.head()
# Out:
#      lambda   eval_rm  predicted_prob   token_count       time  \
# 0  0.000010  0.901713        0.893827  29210.816887  13.041404
# 1  0.000012  0.901713        0.893827  29210.816887  13.041404
# 2  0.000015  0.901713        0.893827  29210.816887  13.041404
# 3  0.000018  0.901713        0.893827  29210.816887  13.041404
# 4  0.000021  0.901713        0.893827  29210.816887  13.041404
#
#             method
# 0  adaptive_router
# 1  adaptive_router
# 2  adaptive_router
# 3  adaptive_router
# 4  adaptive_router

# %%
oracle_tc.head()
# Out:
#          lambda   eval_rm  predicted_prob  token_count      time  method
# 0  1.000000e-07  0.996395        0.834288  4426.835198  6.135344  oracle
# 1  1.325711e-07  0.996380        0.833775  4299.052899  6.074365  oracle
# 2  1.757511e-07  0.996363        0.833417  4194.870804  6.024428  oracle
# 3  2.329952e-07  0.996310        0.832730  3951.703967  5.914374  oracle
# 4  3.088844e-07  0.996238        0.832079  3687.269583  5.804481  oracle

# %%
oracle_lat.head()
# Out:
#      lambda   eval_rm  predicted_prob  token_count      time  method
# 0  0.000010  0.996449        0.841872  6912.746694  6.723552  oracle
# 1  0.000012  0.996448        0.841341  6710.695829  6.649338  oracle
# 2  0.000015  0.996447        0.840994  6598.701933  6.573139  oracle
# 3  0.000018  0.996446        0.840704  6466.565615  6.527243  oracle
# 4  0.000021  0.996445        0.840379  6383.668362  6.471963  oracle

# %% [markdown]
# Fill in "-1"'s for the configuration-related columns for the router + oracle.

# %%
adaptive_oracle_tc['N'] = -1
adaptive_oracle_lat['N'] = -1
adaptive_tc['N'] = -1
adaptive_lat['N'] = -1
oracle_tc['N'] = -1
oracle_lat['N'] = -1

# %%
config_summary_df.rename(columns={"calibrated_probs": "predicted_prob"}, inplace=True)

# %%
config_summary_df['method'] = 'static'

# %%
adaptive_oracle_tc['method'] = 'oracle_cost'
adaptive_oracle_lat['method'] = 'oracle_cost'

# %%
config_summary_df.head()
# Out:
#     N   token_count       time   eval_rm  predicted_prob  token_count_pred  \
# 0   1    875.247743   4.388919  0.765076        0.821887        916.341744
# 1   2   1829.339891   6.212457  0.807857        0.823924       1817.973677
# 2   4   3643.478435   7.968400  0.849004        0.830441       3640.493880
# 3   8   7295.425276   9.262573  0.868470        0.841305       7308.048713
# 4  16  14564.878636  10.355629  0.874678        0.861181      14577.723707
#
#    time_pred  method
# 0   4.597295  static
# 1   6.199320  static
# 2   7.925942  static
# 3   9.035709  static
# 4  10.368374  static

# %%
# outer join on the shared columns
df_1_tc = pd.merge(
    adaptive_tc,
    config_summary_df,
    on=["eval_rm", "token_count", "time", "predicted_prob", "N", "method"],
    how="outer"
)
df_2_tc = pd.merge(
    df_1_tc,
    oracle_tc,
    on=["lambda", "eval_rm", "token_count", "time", "predicted_prob", "N", "method"],
    how="outer"
)
df_3_tc = pd.merge(
    df_2_tc,
    adaptive_oracle_tc,
    on=["lambda", "eval_rm", "token_count", "time", "predicted_prob", "N", "method"],
    how="outer"
)
# Replace NaN values with -1 for plotting purposes
query_optimal_tc = df_3_tc.fillna(-1)

# %%
query_optimal_tc['method'].unique()
# Out:
# array(['adaptive_router', 'oracle_cost', 'oracle', 'static'], dtype=object)

# %%
# outer join on the shared columns
df_1_lat = pd.merge(
    adaptive_lat,
    config_summary_df,
    on=["eval_rm", "token_count", "time", "predicted_prob", "N", "method"],
    how="outer"
)
df_2_lat = pd.merge(
    df_1_lat,
    oracle_lat,
    on=["lambda", "eval_rm", "token_count", "time", "predicted_prob", "N", "method"],
    how="outer"
)
df_3_lat = pd.merge(
    df_2_lat,
    adaptive_oracle_lat,
    on=["lambda", "eval_rm", "token_count", "time", "predicted_prob", "N", "method"],
    how="outer"
)
# Replace NaN values with -1 for plotting purposes
query_optimal_lat = df_3_lat.fillna(-1)

# %%
# router on token count.
method_colors = {
    "oracle_cost": "purple",  # Query-adaptive router with oracle cost
    "adaptive_router": "red",  # Query-adaptive router
    "oracle": "gray",  # Oracle router
    "static": "blue",
}

# Create a figure
plt.figure(figsize=(10, 6))

# Iterate over each method and plot its points and connecting lines
for method in query_optimal_tc["method"].unique():
    # if method != "oracle_cost":
    method_df = query_optimal_tc[query_optimal_tc["method"] == method].sort_values("token_count")
    color = method_colors.get(method, "adaptive")  # Default to gray if method is unknown
    plt.plot(
        method_df["token_count"], 
        method_df["eval_rm"], 
        marker="o", 
        linestyle="-", 
        color=color, 
        label=method,
        markersize=4,
        linewidth=1
    )

# Add labels and title
plt.xlabel("Average Token Count (per query)", fontsize=14)
plt.ylabel("Score", fontsize=14)
# plt.title("Accuracy vs Cost per Configuration", fontsize=20)
plt.legend(title="Method", fontsize=12)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### View oracle costs.

# %%
# router on token count.
method_colors = {
    "oracle_cost": "purple",  # Query-adaptive router with oracle cost
    "adaptive_router": "red",  # Query-adaptive router
    "oracle": "gray",  # Oracle router
    "static": "blue",
}

# Create a figure
plt.figure(figsize=(10, 6))

# Iterate over each method and plot its points and connecting lines
for method in query_optimal_lat["method"].unique():
    # if method != "oracle_cost":
    method_df = query_optimal_lat[query_optimal_lat["method"] == method].sort_values("time")
    color = method_colors.get(method, "adaptive")  # Default to gray if method is unknown
    plt.plot(
        method_df["time"], 
        method_df["eval_rm"], 
        marker="o", 
        linestyle="-", 
        color=color, 
        label=method,
        markersize=4,
        linewidth=1
    )

# Add labels and title
plt.xlabel("Average Time per Query (in sec)", fontsize=14)
plt.ylabel("Score", fontsize=14)
# plt.title("Accuracy vs Cost per Configuration", fontsize=20)
plt.legend(title="Method", fontsize=12)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Likely, the router would do better if we divided the prompts up by subject-area (because range of subjects is too diverse).
